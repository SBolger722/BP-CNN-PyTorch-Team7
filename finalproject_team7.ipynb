# %% [markdown]
# <a href="https://colab.research.google.com/github/SBolger722/BP-CNN-PyTorch-Team7/blob/master/finalproject_team7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/Shareddrives/FinalProject_446/BP-CNN-PyTorch-Team7
# Out:
# /content/drive/Shareddrives/FinalProject_446/BP-CNN-PyTorch-Team7

# %%
# %cd /content/drive/Shareddrives/FinalProject_446/BP-CNN-Tensorflow-Team7
# Out:
# /content/drive/Shareddrives/FinalProject_446/BP-CNN-Tensorflow-Team7

# %%
# !python3 main.py -Func Train

# %%
# %%bash
# for val in 0.5 0.6 0.7 0.8 0.9 1.0
# do
#     echo "Running simulation for CorrPara: $val"
#     python3 main.py -Func Simulation -SimuCorrPara $val
# done

# %%
# !python3 verify_whole.py
# Out:
# Keys found in TF weights file:
# b0:0
# b1:0
# b2:0
# b3:0
# conv_layer0:0
# conv_layer1:0
# conv_layer2:0
# conv_layer3:0
# Transplanting weights...
# Loading conv_layer0:0 into layer 0...
# Loading conv_layer1:0 into layer 1...
# Loading conv_layer2:0 into layer 2...
# Loading conv_layer3:0 into layer 3...
# PyTorch output saved to verification_data_pt/pt_output.npy

# %%
# !python3 compare_whole.py
# Out:
# Max Difference: 0.052093505859375
# Models diverge in absolute terms.
#
#
# TF: [237.36761  194.51176  442.594    374.93997  224.83745  109.237404
#   42.94795   87.16737  326.89758  387.34833  295.96548  379.65692
#  285.5218   436.455    326.4992  ]
# PT: [237.35547  194.5058   442.59772  374.95413  224.85255  109.22577
#   42.948166  87.16713  326.91534  387.3605   295.97076  379.67743
#  285.52335  436.46384  326.49915 ]
# Max Relative Difference: 0.000151 (0.0151%)
# SUCCESS: The models are functionally equivalent.

# %%
# !python3 verify_layer.py
# Out:
# Loading spy data...
#
# --- RAW LAYER COMPARISON (Relative) ---
# Layer_0: Abs 0.000070 | Rel 8.6825% 	 [PASS]
# Layer_1: Abs 0.000490 | Rel 7.1335% 	 [PASS]
# Layer_2: Abs 0.003052 | Rel 9.4489% 	 [PASS]
# Layer_3: Abs 0.028381 | Rel 0.0137% 	 [PASS]
